# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr

# %%
#Correlation: Master's degrees in Military technologies (USA) vs. Wind power in Kazakhstan (2012-2021)
#Statistics: r=0.996, r²=0.992, p<0.01

# %%
# A. Impact If True
#If causal, this would indicate U.S. military technology graduates directly drive Kazakhstan's wind energy development—suggesting unprecedented defense-energy cooperation between the two nations. 
#This would imply American military education is critical infrastructure for Central Asian renewable energy, fundamentally reshaping international development and defense diplomacy strategies.

# %%
#B
#How likely in real datasets?Very common. Spurious correlations arise from:
#Testing many variable pairs (more tests = more false positives)
#Small sample sizes (10 years here increases chance correlation)
#Expected rate: ~1 in 100 tests at p<0.01 significance level

#How to identify false correlations:
#Test causal plausibility - No credible mechanism linking these variables
#Check for confounders - Both likely driven by independent growth trends
#Verify temporal precedence - Does one predict the other?
#Replicate on new data - Does it hold in other periods/regions?
#Apply domain knowledge - Experts recognize implausible relationships

# %%
df2 = pd.read_csv('C:/Users/ABC/Downloads/climate_change_dataset.csv')
df3 = pd.read_csv('C:/Users/ABC/Downloads/world_bank_dataset.csv')
